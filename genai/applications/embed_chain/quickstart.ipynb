# %%
import os
import dotenv

dotenv.load_dotenv()

from embedchain import App
app = App.from_config("mistral.yaml")
# From tutorial
# app.add("https://www.forbes.com/profile/elon-musk")
# app.add("https://en.wikipedia.org/wiki/Elon_Musk")
# answer = app.query("What is the net worth of Elon Musk today?")
# Answer: The net worth of Elon Musk today is $258.7 billion.
app.add("../../../site/sitemap.xml", data_type="sitemap")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[5], line 13
#       7 app = App.from_config("mistral.yaml")
#       8 # From tutorial
#       9 # app.add("https://www.forbes.com/profile/elon-musk")
#      10 # app.add("https://en.wikipedia.org/wiki/Elon_Musk")
#      11 # answer = app.query("What is the net worth of Elon Musk today?")
#      12 # Answer: The net worth of Elon Musk today is $258.7 billion.
# ---> 13 app.add("../../../site/sitemap.xml", data_type="sitemap")
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/embedchain/embedchain.py:201, in EmbedChain.add(self, source, data_type, metadata, config, dry_run, loader, chunker, **kwargs)
#     198 self.user_asks.append([source, data_type.value, metadata])
#     200 data_formatter = DataFormatter(data_type, config, loader, chunker)
# --> 201 documents, metadatas, _ids, new_chunks = self._load_and_embed(
#     202     data_formatter.loader, data_formatter.chunker, source, metadata, source_hash, config, dry_run, **kwargs
#     203 )
#     204 if data_type in {DataType.DOCS_SITE}:
#     205     self.is_docs_site_instance = True
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/embedchain/embedchain.py:366, in EmbedChain._load_and_embed(self, loader, chunker, src, metadata, source_hash, add_config, dry_run, **kwargs)
#     363 app_id = self.config.id if self.config is not None else None
#     365 # Create chunks
# --> 366 embeddings_data = chunker.create_chunks(loader, src, app_id=app_id, config=add_config.chunker)
#     367 # spread chunking results
#     368 documents = embeddings_data["documents"]
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/embedchain/chunkers/base_chunker.py:31, in BaseChunker.create_chunks(self, loader, src, app_id, config)
#      29 min_chunk_size = config.min_chunk_size if config is not None else 1
#      30 logging.info(f"[INFO] Skipping chunks smaller than {min_chunk_size} characters")
# ---> 31 data_result = loader.load_data(src)
#      32 data_records = data_result["data"]
#      33 doc_id = data_result["doc_id"]
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/embedchain/loaders/sitemap.py:45, in SitemapLoader.load_data(self, sitemap_source)
#      43 elif os.path.isfile(sitemap_source):
#      44     with open(sitemap_source, "r") as file:
# ---> 45         soup = BeautifulSoup(file, "xml")
#      46 else:
#      47     raise ValueError("Invalid sitemap source. Please provide a valid URL or local file path.")
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/bs4/__init__.py:250, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     248     builder_class = builder_registry.lookup(*features)
#     249     if builder_class is None:
# --> 250         raise FeatureNotFound(
#     251             "Couldn't find a tree builder with the features you "
#     252             "requested: %s. Do you need to install a parser library?"
#     253             % ",".join(features))
#     255 # At this point either we have a TreeBuilder instance in
#     256 # builder, or we have a builder_class that we can instantiate
#     257 # with the remaining **kwargs.
#     258 if builder is None:
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: xml. Do you need to install a parser library?

# %%
answer = app.query("What are some front ends for LLM applications?")
# Out:
# "\n  Elon Musk's net worth is estimated to be around $200 billion as of December 2022.\n\n  Elon Musk is a South African-born American entrepreneur and businessman who is the founder, CEO, and chief engineer of SpaceX; early-stage investor, CEO, and product architect of Tesla, Inc.; founder of The Boring Company; co-founder of Neuralink; and co-founder and initial co-chairman of OpenAI. He is also the founder and CEO of the aerospace manufacturer SpaceX, the electric vehicle manufacturer Tesla, and the solar energy products company SolarCity.\n\n  Musk was born in Pretoria, South Africa, and moved to Canada at the age of 17. He then moved to the United States in 1995 and became a naturalized citizen in 2002. He has been a major investor in several companies, including Tesla, SpaceX, and SolarCity.\n\n  Musk's net worth is estimated to be around $200 billion as of December 2022. This is based on his ownership of Tesla and SpaceX stock, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX, as well as his other investments.\n\n  Musk's net worth has been on a steady rise since he founded Tesla in 2003. He has been able to increase his net worth through his investments in Tesla and SpaceX,"

# %%
import os
# replace this with your OpenAI key
# os.environ["OPENAI_API_KEY"] = "sk-xxxx"

from embedchain import App
app = App()
app.add("https://www.forbes.com/profile/elon-musk")
app.add("https://en.wikipedia.org/wiki/Elon_Musk")
app.query("What is the net worth of Elon Musk today?")
# Answer: The net worth of Elon Musk today is $258.7 billion.
# Out:
# Inserting batches in chromadb:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[12], line 7
#       5 from embedchain import App
#       6 app = App()
# ----> 7 app.add("https://www.forbes.com/profile/elon-musk")
#       8 app.add("https://en.wikipedia.org/wiki/Elon_Musk")
#       9 app.query("What is the net worth of Elon Musk today?")
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/embedchain/embedchain.py:201, in EmbedChain.add(self, source, data_type, metadata, config, dry_run, loader, chunker, **kwargs)
#     198 self.user_asks.append([source, data_type.value, metadata])
#     200 data_formatter = DataFormatter(data_type, config, loader, chunker)
# --> 201 documents, metadatas, _ids, new_chunks = self._load_and_embed(
#     202     data_formatter.loader, data_formatter.chunker, source, metadata, source_hash, config, dry_run, **kwargs
#     203 )
#     204 if data_type in {DataType.DOCS_SITE}:
#     205     self.is_docs_site_instance = True
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/embedchain/embedchain.py:436, in EmbedChain._load_and_embed(self, loader, chunker, src, metadata, source_hash, add_config, dry_run, **kwargs)
#     433 # Count before, to calculate a delta in the end.
#     434 chunks_before_addition = self.db.count()
# --> 436 self.db.add(
#     437     embeddings=embeddings,
#     438     documents=documents,
#     439     metadatas=metadatas,
#     440     ids=ids,
#     441     **kwargs,
#     442 )
#     443 count_new_chunks = self.db.count() - chunks_before_addition
#     445 print((f"Successfully saved {src} ({chunker.data_type}). New chunks count: {count_new_chunks}"))
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/embedchain/vectordb/chroma.py:157, in ChromaDB.add(self, embeddings, documents, metadatas, ids, **kwargs)
#     151     raise ValueError(
#     152         "Cannot add documents to chromadb with inconsistent sizes. Documents size: {}, Metadata size: {},"
#     153         " Ids size: {}".format(len(documents), len(metadatas), len(ids))
#     154     )
#     156 for i in tqdm(range(0, len(documents), self.BATCH_SIZE), desc="Inserting batches in chromadb"):
# --> 157     self.collection.add(
#     158         documents=documents[i : i + self.BATCH_SIZE],
#     159         metadatas=metadatas[i : i + self.BATCH_SIZE],
#     160         ids=ids[i : i + self.BATCH_SIZE],
#     161     )
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/chromadb/api/models/Collection.py:154, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#     151 if embeddings is None:
#     152     # At this point, we know that one of documents or images are provided from the validation above
#     153     if documents is not None:
# --> 154         embeddings = self._embed(input=documents)
#     155     elif images is not None:
#     156         embeddings = self._embed(input=images)
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/chromadb/api/models/Collection.py:633, in Collection._embed(self, input)
#     628 if self._embedding_function is None:
#     629     raise ValueError(
#     630         "You must provide an embedding function to compute embeddings."
#     631         "https://docs.trychroma.com/embeddings"
#     632     )
# --> 633 return self._embedding_function(input=input)
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/chromadb/utils/embedding_functions.py:177, in OpenAIEmbeddingFunction.__call__(self, input)
#     175 # Call the OpenAI Embedding API
#     176 if self._v1:
# --> 177     embeddings = self._client.create(
#     178         input=input, model=self._deployment_id or self._model_name
#     179     ).data
#     181     # Sort resulting embeddings by index
#     182     sorted_embeddings = sorted(
#     183         embeddings, key=lambda e: e.index
#     184     )  # type: ignore
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/openai/resources/embeddings.py:106, in Embeddings.create(self, input, model, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     100         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     101             base64.b64decode(data), dtype="float32"
#     102         ).tolist()
#     104     return obj
# --> 106 return self._post(
#     107     "/embeddings",
#     108     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     109     options=make_request_options(
#     110         extra_headers=extra_headers,
#     111         extra_query=extra_query,
#     112         extra_body=extra_body,
#     113         timeout=timeout,
#     114         post_parser=parser,
#     115     ),
#     116     cast_to=CreateEmbeddingResponse,
#     117 )
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/openai/_base_client.py:1088, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1074 def post(
#    1075     self,
#    1076     path: str,
#    (...)
#    1083     stream_cls: type[_StreamT] | None = None,
#    1084 ) -> ResponseT | _StreamT:
#    1085     opts = FinalRequestOptions.construct(
#    1086         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1087     )
# -> 1088     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/openai/_base_client.py:853, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     844 def request(
#     845     self,
#     846     cast_to: Type[ResponseT],
#    (...)
#     851     stream_cls: type[_StreamT] | None = None,
#     852 ) -> ResponseT | _StreamT:
# --> 853     return self._request(
#     854         cast_to=cast_to,
#     855         options=options,
#     856         stream=stream,
#     857         stream_cls=stream_cls,
#     858         remaining_retries=remaining_retries,
#     859     )
#
# File ~/miniconda3/envs/embedchain_py310/lib/python3.10/site-packages/openai/_base_client.py:930, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927     if not err.response.is_closed:
#     928         err.response.read()
# --> 930     raise self._make_status_error_from_response(err.response) from None
#     932 return self._process_response(
#     933     cast_to=cast_to,
#     934     options=options,
#    (...)
#     937     stream_cls=stream_cls,
#     938 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-xxxx. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 app.add("../../site/sitemap.xml", data_type="sitemap")
#
# NameError: name 'app' is not defined
